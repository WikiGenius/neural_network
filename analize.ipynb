# %%
import importlib
import data_prep
importlib.reload(data_prep)

data, features, targets = data_prep.data, data_prep.features, data_prep.targets

# %%
features
# Out:
# array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])

# %%
targets
# Out:
# array([0, 0, 0, 1])

# %%
# Importing matplotlib
import matplotlib.pyplot as plt
import numpy as np
# Function to help us plot
def plot_points(data,title):
    
    admitted = data[data['y']==1]
    rejected = data[data['y']==0]
    plt.scatter(admitted['x1'],admitted['x2'], s = 25, color = 'cyan', edgecolor = 'k')
    plt.scatter(rejected['x1'],rejected['x2'], s = 25, color = 'red', edgecolor = 'k')
    plt.xlabel('x1')
    plt.ylabel('x2')
    plt.title(title)

# %%
# Plotting the points
# before processing
plot_points(data,"AND")
plt.show()

# %%
# Plotting the points
# After processing
plot_points(data,"AND")
x = np.arange(-1,1,0.1)
m = -(3.26354248)/(3.30767106)
plt.plot(x,m*x)
plt.show()
